# %%
import ast
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "serif"

with open(
        "test_results/bloom/qwen/level_ragas_scores_awf_20250804_220453.txt",
    "r",
    encoding="utf-8",
) as f1:
    data1 = ast.literal_eval(f1.read().strip())

with open(
        "test_results/bloom/qwen/level_ragas_scores_20250812_002700.txt",
    "r",
    encoding="utf-8",
) as f2:
    data2 = ast.literal_eval(f2.read().strip())

with open(
        'test_results/bloom/qwen/level_ragas_scores_awf_20250813_071237.txt',
    "r",
    encoding="utf-8",
) as f3:
    data3 = ast.literal_eval(f3.read().strip())

metrics = list(data1.keys())
scores1 = list(data1.values())
scores2 = list(data2.values())
scores3 = list(data3.values())

x = np.arange(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 9))

bars1 = ax.bar(
    x - width, scores1, width, label="Agent-wise feedback", color="#4E79A7", hatch="//"
)
bars2 = ax.bar(
    x,
    scores2,
    width,
    label="Generator-only feedback",
    color="#F28E2B",
    hatch="\\\\"
)

bars3 = ax.bar(
    x + width,
    scores3,
    width,
    label="No feedback",
    color="#59A14F",
    hatch=".."
)

ax.bar_label(bars1, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars2, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars3, fmt="%.3f", padding=2, fontsize=9)

ax.set_ylim(0, 1.05)
ax.set_ylabel("Score", fontsize=12)
ax.set_xlabel("Metric", fontsize=12)
ax.set_title("RAGAS Metrics Comparison", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=10)
ax.tick_params(axis="y", labelsize=10)
ax.grid(True, axis="y", linestyle="--", alpha=0.7)

ax.set_ylim(0, 1.1)

ax.text(
    0.02, 0.98, "qwen3:1.7b",
    transform=ax.transAxes,
    fontsize=13, fontweight="bold", va="top", ha="left",
    bbox=dict(boxstyle="round,pad=0.3", facecolor="#F0F0F0", edgecolor="#4E79A7", alpha=0.9)
)

# Move legend below plot
ax.legend(
    loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=10
)

plt.tight_layout()
plt.savefig("ragas_metrics_comparison.png", bbox_inches="tight", dpi=300)  # optional for saving
plt.show()

# %%
import ast
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "serif"

with open(
    "test_results/bloom/level_ragas_scores_awf_20250811_153504.txt",
    "r",
    encoding="utf-8",
) as f1:
    data1 = ast.literal_eval(f1.read().strip())

with open(
    "test_results/bloom/deepseek/level_ragas_scores_20250811_224419.txt",
    "r",
    encoding="utf-8",
) as f2:
    data2 = ast.literal_eval(f2.read().strip())

with open(
    'test_results/bloom/deepseek/level_ragas_scores_baseline_20250811_180740.txt',
    "r",
    encoding="utf-8",
) as f3:
    data3 = ast.literal_eval(f3.read().strip())

metrics = list(data1.keys())
scores1 = list(data1.values())
scores2 = list(data2.values())
scores3 = list(data3.values())

x = np.arange(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 9))

bars1 = ax.bar(
    x - width, scores1, width, label="Agent-wise feedback", color="#4E79A7", hatch="//"
)
bars2 = ax.bar(
    x,
    scores2,
    width,
    label="Generator-only feedback",
    color="#F28E2B",
    hatch="\\\\"
)

bars3 = ax.bar(
    x + width,
    scores3,
    width,
    label="No feedback",
    color="#59A14F",
    hatch=".."
)

ax.bar_label(bars1, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars2, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars3, fmt="%.3f", padding=2, fontsize=9)

ax.set_ylim(0, 1.05)
ax.set_ylabel("Score", fontsize=12)
ax.set_xlabel("Metric", fontsize=12)
ax.set_title("RAGAS Metrics Comparison", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=10)
ax.tick_params(axis="y", labelsize=10)
ax.grid(True, axis="y", linestyle="--", alpha=0.7)

ax.set_ylim(0, 1.1)

ax.text(
    0.02, 0.98, "deepseek-r1:1.5b",
    transform=ax.transAxes,
    fontsize=13, fontweight="bold", va="top", ha="left",
    bbox=dict(boxstyle="round,pad=0.3", facecolor="#F0F0F0", edgecolor="#4E79A7", alpha=0.9)
)

# Move legend below plot
ax.legend(
    loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=10
)

plt.tight_layout()
plt.savefig("ragas_metrics_comparison_deepseek.png", bbox_inches="tight", dpi=300)  # optional for saving
plt.show()

# %%
import ast
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "serif"

with open(
    "test_results/bloom/llama3/level_ragas_scores_awf_20250814_034440.txt",
    "r",
    encoding="utf-8",
) as f1:
    data1 = ast.literal_eval(f1.read().strip())

with open(
    "test_results/bloom/llama3/level_ragas_scores_20250809_122327.txt",
    "r",
    encoding="utf-8",
) as f2:
    data2 = ast.literal_eval(f2.read().strip())

with open(
    'test_results/bloom/llama3/level_ragas_scores_baseline_20250811_182621.txt',
    "r",
    encoding="utf-8",
) as f3:
    data3 = ast.literal_eval(f3.read().strip())

metrics = list(data1.keys())
scores1 = list(data1.values())
scores2 = list(data2.values())
scores3 = list(data3.values())

x = np.arange(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 9))

bars1 = ax.bar(
    x - width, scores1, width, label="Agent-wise feedback", color="#4E79A7", hatch="//"
)
bars2 = ax.bar(
    x,
    scores2,
    width,
    label="Generator-only feedback",
    color="#F28E2B",
    hatch="\\\\"
)

bars3 = ax.bar(
    x + width,
    scores3,
    width,
    label="No feedback",
    color="#59A14F",
    hatch=".."
)

ax.bar_label(bars1, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars2, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars3, fmt="%.3f", padding=2, fontsize=9)

ax.set_ylim(0, 1.05)
ax.set_ylabel("Score", fontsize=12)
ax.set_xlabel("Metric", fontsize=12)
ax.set_title("RAGAS Metrics Comparison", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=10)
ax.tick_params(axis="y", labelsize=10)
ax.grid(True, axis="y", linestyle="--", alpha=0.7)

ax.set_ylim(0, 1.1)

ax.text(
    0.02, 0.98, "llama3.2:3b",
    transform=ax.transAxes,
    fontsize=13, fontweight="bold", va="top", ha="left",
    bbox=dict(boxstyle="round,pad=0.3", facecolor="#F0F0F0", edgecolor="#4E79A7", alpha=0.9)
)

# Move legend below plot
ax.legend(
    loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=10
)

plt.tight_layout()
plt.savefig("ragas_metrics_comparison_llama.png", bbox_inches="tight", dpi=300)  # optional for saving
plt.show()

# %%
import ast
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["font.family"] = "serif"

with open(
        "test_results/bloom/qwen8b/level_ragas_scores_awf_20250810_214433.txt",
    "r",
    encoding="utf-8",
) as f1:
    data1 = ast.literal_eval(f1.read().strip())

with open(
        "test_results/bloom/qwen8b/level_ragas_scores_20250812_173920.txt",
    "r",
    encoding="utf-8",
) as f2:
    data2 = ast.literal_eval(f2.read().strip())

with open(
        'test_results/bloom/qwen8b/level_ragas_scores_baseline_20250811_190924.txt',
    "r",
    encoding="utf-8",
) as f3:
    data3 = ast.literal_eval(f3.read().strip())

metrics = list(data1.keys())
scores1 = list(data1.values())
scores2 = list(data2.values())
scores3 = list(data3.values())

x = np.arange(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(12, 9))

bars1 = ax.bar(
    x - width, scores1, width, label="Agent-wise feedback", color="#4E79A7", hatch="//"
)
bars2 = ax.bar(
    x,
    scores2,
    width,
    label="Generator-only feedback",
    color="#F28E2B",
    hatch="\\\\"
)

bars3 = ax.bar(
    x + width,
    scores3,
    width,
    label="No feedback",
    color="#59A14F",
    hatch=".."
)

ax.bar_label(bars1, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars2, fmt="%.3f", padding=2, fontsize=9)
ax.bar_label(bars3, fmt="%.3f", padding=2, fontsize=9)

ax.set_ylim(0, 1.05)
ax.set_ylabel("Score", fontsize=12)
ax.set_xlabel("Metric", fontsize=12)
ax.set_title("RAGAS Metrics Comparison", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(metrics, fontsize=10)
ax.tick_params(axis="y", labelsize=10)
ax.grid(True, axis="y", linestyle="--", alpha=0.7)

ax.set_ylim(0, 1.1)

ax.text(
    0.02, 0.98, "qwen3:8b",
    transform=ax.transAxes,
    fontsize=13, fontweight="bold", va="top", ha="left",
    bbox=dict(boxstyle="round,pad=0.3", facecolor="#F0F0F0", edgecolor="#4E79A7", alpha=0.9)
)

# Move legend below plot
ax.legend(
    loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=2, frameon=False, fontsize=10
)

plt.tight_layout()
plt.savefig("ragas_metrics_comparison_deepseek8b.png", bbox_inches="tight", dpi=300)  # optional for saving
plt.show()

# %%
from PIL import Image

img1 = Image.open("graphs/ragas_metrics_comparison_deepseek.png")
img2 = Image.open("graphs/ragas_metrics_comparison.png")
img3 = Image.open("graphs/ragas_metrics_comparison_llama.png")
img4 = Image.open("graphs/ragas_metrics_comparison_deepseek8b.png")

width = img1.width * 2
height = img1.height * 2

new_img = Image.new("RGBA", (width, height))

new_img.paste(img1, (0, 0))
new_img.paste(img2, (img1.width, 0))
new_img.paste(img3, (0, img1.height))
new_img.paste(img4, (img1.width, img1.height))

new_img.save("concatenated_image.png")
